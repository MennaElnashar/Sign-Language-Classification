# %% [markdown]
# # Sign Language Classification

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (16,16))
img = plt.imread('/kaggle/input/sign-language-mnist/amer_sign2.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Prepare Data

# %%
df_train = pd.read_csv('../input/sign-language-mnist/sign_mnist_train/sign_mnist_train.csv')
df_train.head(-5)
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     14     167     169     170     171     171     172     172     172
# 27446     19     133     135     138     141     143     144     144     145
# 27447     11     170     172     175     177     179     182     185     186
# 27448     12     149     151     153     157     159     161     164     165
# 27449     20     162     168     172     176     179     183     184     185
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27445     171  ...       215       215       211       208       211
# 27446     145  ...         0         0         1         4         4
# 27447     187  ...       221       228       229       228       229
# 27448     168  ...       108       165       167       163       159
# 27449     188  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 785 columns]

# %%
df_test = pd.read_csv('../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv')
df_test.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     10     130     131     131     134     133     135     137     136
# 7163      4     158     161     165     169     172     175     177     179
# 7164     14     141     144     146     149     153     156     158     161
# 7165      8     158     160     160     161     161     161     164     162
# 7166     12     169     173     177     181     183     186     189     191
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        151  ...       138       148       127        89        82        96
# 1        136  ...        47       104       194       183       186       184
# 2        147  ...        68       166       242       227       230       227
# 3        210  ...       154       248       247       248       253       236
# 4        203  ...        26        40        64        48        29        46
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 7162     136  ...       128       106       107        63        11       147
# 7163     181  ...        78       122       141       141       141       140
# 7164     161  ...       199       203       202       201       201       201
# 7165     162  ...       177       178       176       174       173       172
# 7166     194  ...        36        27        14        35        40        15
#
#       pixel781  pixel782  pixel783  pixel784
# 0          106       112       120       107
# 1          184       184       182       180
# 2          226       225       224       222
# 3          230       240       253       255
# 4           49        46        46        53
# ...        ...       ...       ...       ...
# 7162       194       182       176       124
# 7163       141       142       143       144
# 7164       200       200       201       201
# 7165       171       169       169       167
# 7166         8        27        42        41
#
# [7167 rows x 785 columns]

# %%
plt.figure(figsize = (15,10))
sns.set_style("darkgrid")
sns.countplot(df_train['label'])
plt.show()

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head(-5)
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0         107     118     127     134     139     143     146     150     153
# 1         155     157     156     156     156     157     156     158     158
# 2         187     188     188     187     187     186     187     188     187
# 3         211     211     212     212     211     210     211     210     210
# 4         164     167     170     172     176     179     180     184     185
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     167     169     170     171     171     172     172     172     171
# 27446     133     135     138     141     143     144     144     145     145
# 27447     170     172     175     177     179     182     185     186     187
# 27448     149     151     153     157     159     161     164     165     168
# 27449     162     168     172     176     179     183     184     185     188
#
#        pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0          156  ...       207       207       207       207       206
# 1          157  ...        69       149       128        87        94
# 2          186  ...       202       201       200       199       198
# 3          211  ...       235       234       233       231       230
# 4          186  ...        92       105       105       108       133
# ...        ...  ...       ...       ...       ...       ...       ...
# 27445      172  ...       215       215       211       208       211
# 27446      145  ...         0         0         1         4         4
# 27447      188  ...       221       228       229       228       229
# 27448      171  ...       108       165       167       163       159
# 27449      190  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 784 columns]

# %%
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
df_test.head(-5)
# Out:
#       pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0        149     149     150     150     150     151     151     150     151
# 1        126     128     131     132     133     134     135     135     136
# 2         85      88      92      96     105     123     135     143     147
# 3        203     205     207     206     207     209     210     209     210
# 4        188     191     193     195     199     201     202     203     203
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     130     131     131     134     133     135     137     136     136
# 7163     158     161     165     169     172     175     177     179     181
# 7164     141     144     146     149     153     156     158     161     161
# 7165     158     160     160     161     161     161     164     162     162
# 7166     169     173     177     181     183     186     189     191     194
#
#       pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         152  ...       138       148       127        89        82
# 1         138  ...        47       104       194       183       186
# 2         152  ...        68       166       242       227       230
# 3         209  ...       154       248       247       248       253
# 4         203  ...        26        40        64        48        29
# ...       ...  ...       ...       ...       ...       ...       ...
# 7162      137  ...       128       106       107        63        11
# 7163      184  ...        78       122       141       141       141
# 7164      161  ...       199       203       202       201       201
# 7165      161  ...       177       178       176       174       173
# 7166      195  ...        36        27        14        35        40
#
#       pixel780  pixel781  pixel782  pixel783  pixel784
# 0           96       106       112       120       107
# 1          184       184       184       182       180
# 2          227       226       225       224       222
# 3          236       230       240       253       255
# 4           46        49        46        46        53
# ...        ...       ...       ...       ...       ...
# 7162       147       194       182       176       124
# 7163       140       141       142       143       144
# 7164       201       200       200       201       201
# 7165       172       171       169       169       167
# 7166        15         8        27        42        41
#
# [7167 rows x 784 columns]

# %%
size  = 28
channels = 1
batch = 128
epochs = 50

# %%
X_train = df_train.values.reshape(df_train.shape[0], size, size, channels)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (27455, 28, 28, 1)
# X_test shape: (7172, 28, 28, 1)

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.show()

# %% [markdown]
# ## Setup Callbacks

# %%
checkpoint_filepath = 'best_model.hdf5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %% [markdown]
# ## Design the Neural Network

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                 
                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                
                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                    
                    
                    Flatten(),
                    
                    Dense(units=4096, activation="relu"),                 
                    Dropout(0.2),
                    
                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),
                                  
                    Dense(units=256, activation="relu"),
                    Dropout(0.2),
                    
                    Dense(units=25, activation="softmax"),
])


Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 512)         590336
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 13,484,505
# Trainable params: 13,484,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/50
# 215/215 [==============================] - 21s 75ms/step - loss: 3.1131 - accuracy: 0.0618 - val_loss: 2.9635 - val_accuracy: 0.0722
# Epoch 2/50
# 215/215 [==============================] - 14s 67ms/step - loss: 2.3718 - accuracy: 0.2184 - val_loss: 1.6437 - val_accuracy: 0.4364
# Epoch 3/50
# 215/215 [==============================] - 15s 70ms/step - loss: 1.4811 - accuracy: 0.4838 - val_loss: 0.7476 - val_accuracy: 0.7526
# Epoch 4/50
# 215/215 [==============================] - 15s 70ms/step - loss: 1.0128 - accuracy: 0.6455 - val_loss: 0.4551 - val_accuracy: 0.8574
# Epoch 5/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.7489 - accuracy: 0.7386 - val_loss: 0.3031 - val_accuracy: 0.9020
# Epoch 6/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.6260 - accuracy: 0.7842 - val_loss: 0.2649 - val_accuracy: 0.9223
# Epoch 7/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.5261 - accuracy: 0.8226 - val_loss: 0.2161 - val_accuracy: 0.9285
# Epoch 8/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.4681 - accuracy: 0.8444 - val_loss: 0.1442 - val_accuracy: 0.9502
# Epoch 9/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.3927 - accuracy: 0.8655 - val_loss: 0.0987 - val_accuracy: 0.9685
# Epoch 10/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.3447 - accuracy: 0.8870 - val_loss: 0.1671 - val_accuracy: 0.9481
# Epoch 11/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.3064 - accuracy: 0.8976 - val_loss: 0.1036 - val_accuracy: 0.9660
# Epoch 12/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.2867 - accuracy: 0.9033 - val_loss: 0.0807 - val_accuracy: 0.9738
# Epoch 13/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.2638 - accuracy: 0.9154 - val_loss: 0.0826 - val_accuracy: 0.9697
# Epoch 14/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.2588 - accuracy: 0.9129 - val_loss: 0.0656 - val_accuracy: 0.9788
# Epoch 15/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.2445 - accuracy: 0.9218 - val_loss: 0.1241 - val_accuracy: 0.9564
# Epoch 16/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.2275 - accuracy: 0.9276 - val_loss: 0.0628 - val_accuracy: 0.9841
# Epoch 17/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.2250 - accuracy: 0.9266 - val_loss: 0.0652 - val_accuracy: 0.9777
# Epoch 18/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1926 - accuracy: 0.9364 - val_loss: 0.1134 - val_accuracy: 0.9615
# Epoch 19/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.2020 - accuracy: 0.9345 - val_loss: 0.0815 - val_accuracy: 0.9706
# Epoch 20/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1816 - accuracy: 0.9427 - val_loss: 0.0885 - val_accuracy: 0.9650
# Epoch 21/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.1798 - accuracy: 0.9449 - val_loss: 0.0505 - val_accuracy: 0.9855
# Epoch 22/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.1867 - accuracy: 0.9399 - val_loss: 0.0581 - val_accuracy: 0.9830
# Epoch 23/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.1726 - accuracy: 0.9443 - val_loss: 0.0363 - val_accuracy: 0.9883
# Epoch 24/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.1587 - accuracy: 0.9466 - val_loss: 0.0440 - val_accuracy: 0.9851
# Epoch 25/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1630 - accuracy: 0.9497 - val_loss: 0.0528 - val_accuracy: 0.9837
# Epoch 26/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1647 - accuracy: 0.9466 - val_loss: 0.0349 - val_accuracy: 0.9907
# Epoch 27/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1526 - accuracy: 0.9537 - val_loss: 0.0553 - val_accuracy: 0.9854
# Epoch 28/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1485 - accuracy: 0.9522 - val_loss: 0.0411 - val_accuracy: 0.9873
# Epoch 29/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1396 - accuracy: 0.9552 - val_loss: 0.0399 - val_accuracy: 0.9883
# Epoch 30/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.1405 - accuracy: 0.9535 - val_loss: 0.0309 - val_accuracy: 0.9908
# Epoch 31/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.1280 - accuracy: 0.9582 - val_loss: 0.0440 - val_accuracy: 0.9881
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# Epoch 32/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.1208 - accuracy: 0.9625 - val_loss: 0.0413 - val_accuracy: 0.9893
# Epoch 33/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1002 - accuracy: 0.9677 - val_loss: 0.0380 - val_accuracy: 0.9904
# Epoch 34/50
# 215/215 [==============================] - 15s 69ms/step - loss: 0.1172 - accuracy: 0.9653 - val_loss: 0.0371 - val_accuracy: 0.9866
# Epoch 35/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0973 - accuracy: 0.9677 - val_loss: 0.0532 - val_accuracy: 0.9842
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# Epoch 36/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0962 - accuracy: 0.9694 - val_loss: 0.0174 - val_accuracy: 0.9946
# Epoch 37/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0899 - accuracy: 0.9718 - val_loss: 0.0307 - val_accuracy: 0.9900
# Epoch 38/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0822 - accuracy: 0.9736 - val_loss: 0.0338 - val_accuracy: 0.9900
# Epoch 39/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0849 - accuracy: 0.9738 - val_loss: 0.0192 - val_accuracy: 0.9936
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# Epoch 40/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0785 - accuracy: 0.9763 - val_loss: 0.0307 - val_accuracy: 0.9888
# Epoch 41/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0741 - accuracy: 0.9760 - val_loss: 0.0231 - val_accuracy: 0.9925
# Epoch 42/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0705 - accuracy: 0.9762 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 43/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0757 - accuracy: 0.9764 - val_loss: 0.0233 - val_accuracy: 0.9897
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# Epoch 44/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0608 - accuracy: 0.9795 - val_loss: 0.0186 - val_accuracy: 0.9921
# Epoch 45/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0657 - accuracy: 0.9807 - val_loss: 0.0219 - val_accuracy: 0.9939
# Epoch 46/50
# 215/215 [==============================] - 15s 68ms/step - loss: 0.0593 - accuracy: 0.9817 - val_loss: 0.0221 - val_accuracy: 0.9918
# Epoch 47/50
# 215/215 [==============================] - 15s 70ms/step - loss: 0.0594 - accuracy: 0.9794 - val_loss: 0.0287 - val_accuracy: 0.9902
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# Epoch 48/50
# 215/215 [==============================] - 15s 67ms/step - loss: 0.0593 - accuracy: 0.9804 - val_loss: 0.0173 - val_accuracy: 0.9925
# Epoch 49/50
# 215/215 [==============================] - 15s 71ms/step - loss: 0.0533 - accuracy: 0.9829 - val_loss: 0.0135 - val_accuracy: 0.9955
# Epoch 50/50
# 215/215 [==============================] - 14s 67ms/step - loss: 0.0512 - accuracy: 0.9833 - val_loss: 0.0120 - val_accuracy: 0.9961
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
#   ##  Evaluate the model

# %%
score = Model.evaluate(X_test) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0120 - accuracy: 0.9961
# Test loss: 0.011970899067819118
# Test accuracy: 0.9960959553718567

# %% [markdown]
# ## Confusion Matrix

# %%
df_test = pd.read_csv('../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv')
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (15,15))
sns.heatmap(CM, annot=True, cmap="Blues", fmt = 'g')
plt.xlabel("Predicted Classes")
plt.ylabel("True Classes")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Test

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")
    
plt.show()
